# %%
import easytrader
import time

# %%
user = easytrader.use('gf')
user.prepare('C:\\Users\\nunoyu\\Documents\\gf.json')
# Out:
# 2017-01-04 19:11:21,622 [DEBUG] gftrader.py 54: verify code detect result: d7fyb
# 2017-01-04 19:11:22,190 [INFO] gftrader.py 91: login response: {"error_info":"","success":true}
# 2017-01-04 19:11:23,600 [DEBUG] gftrader.py 142: get account info: var __ctxPath='';              var g_stockholders;            var g_ofstockholders;          var g_client;                  var ver='20170104191123';                    var g_config=Ext.decode("{theme:'blue',modal:'stock',tabstyle:1,tabposition:'top',pageSize:10,homeView:'ServiceView',homeViewName:'服务首页'}");  var g_rzrqstockholders;        var g_ggqqstockholders;        var g_currdate='20170104';var g_valid_flag = false;var id_valid_flag = false;g_client = Ext.decode('{"client_risklevel_name":"进取型","client_risklevel":"5","theme":"blue","current_balance":"463360.61","stockholders":[{"exchange_type":"G","stock_account":"A172195775","seat_no":"23206","exchange_name":"","main_flag":"1"},{"exchange_type":"1","stock_account":"A172195775","seat_no":"23206","exchange_name":"上海","main_flag":"1"},{"exchange_type":"2","stock_account":"0097939068","seat_no":"234800","exchange_name":"深圳","main_flag":"1"}],"last_logindate":"2017-01-04","risk":true,"nick_name":"011028812646","last_op_ip":"187.11.236.57","enable_balance":"463310.61","valid_date":"20180607","client_id":"011028812646","last_logintime":"19:02:10","internal":518,"client_name":"余勇"}');g_stockholders=g_client.stockholders;var g_sysarg=Ext.decode('{"sysId":1,"refreshhq":5000,"requestTimeout":10000,"pageLimitMax":500,"riskValidDate":30,"histQueryDays":30}');var PAGE_LIMIT_MAX=g_sysarg.pageLimitMax;var RISK_VALID_DATE=g_sysarg.riskValidDate;var PAGE_LIMIT_MIN=g_config.pageSize==null?10:g_config.pageSize;Ext.Ajax.timeout=10000;var g_errormsg;var g_ZQTYPE="+-GHIQUXYZuL6";var g_sfcgFundAccount=Ext.decode('[{"money_type":"0","bank_no":"f","bank_name":"招商银行存管","bank_account":"6225880110641603","fund_account":"6409286","bkaccount_status":"0","bkaccount_rights":" ","bkaccount_regflag":"2","main_flag":"1","asset_prop":"0"}]');var g_kfjjAccount=Ext.decode('null');var g_noteinfos;var g_noticeinfos=[];var g_custserver = false;        g_custserver = true;        var hyzq_check_flag = "1";        var g_transferCodes = [];var g_transferClients = [];var g_transferProdNavs = [];var g_productStocks = {"GIR96C":"12700","87604H":"40442958.9","GI357T":"1500","GIXY9T":"2900","GIS64C":"500000","876059":"20000000","876057":"307778630.13","GIX83T":"16100","876050":"10381292.54","GI3L3T":"3600","GIR97C":"6700","GI358T":"2000","87605I":"10175342.46","87605H":"49186738.35","GIS63C":"160000","87605E":"10000000","GIX42T":"600","GIX02T":"1800","GI3H3T":"2500","GIXAZT":"4700","GIXN9T":"143500","GIX84T":"15600","876065":"34395855.83","87605U":"9000000","GIX02F":"1000000","GIX43T":"6800","87605L":"30000000","GI359T":"1500","GI355T":"500","GIR98C":"5200","87602G":"19700000","876029":"83186665.47","876033":"21853998.08","876034":"5127150.68","GIXAYT":"2500","GI3L5T":"500","GIXY6T":"500","87602I":"20195616.43","87602J":"50000000","GIX268T":"11500","876030":"6000000","GIR99C":"36600","87603B":"61642191.78","GIXY8T":"6000","GIX04T":"500","87602Y":"10105863.01","87603U":"21100000","876043":"50661643.83","GIXAXT":"500","876047":"10000000","GIX82T":"36400","876359":"105484931.5","GIXY7T":"1000","876040":"11000000","GIS60C":"1000000","87608E":"102493150.68","87608A":"61495890.41","GI1A7T":"3000","87608B":"10000000","87608K":"51221643.83","GI1E8T":"1300","876330":"50618082.19","GI353T":"700","87608J":"10000000","87608S":"80000000","87608V":"50000000","87608U":"19000000","876096":"40282100.62","GIXAWT":"2500","GIXF8C":"3800","GIXY4T":"16800","GIQ88C":"4200","876098":"102621369.86","87609F":"10000000","87609G":"629470684.93","87609D":"82189589.04","87609E":"26278235.61","GI1A8T":"2000","GIX06T":"3000","87609H":"20958684.93","87609I":"15000000","GI3L0T":"13100","GIXF9C":"8900","GIXY5T":"2600","GIXAVT":"6000","GIQ87C":"25500","GI3H2T":"1000","87606H":"100000000","87606L":"66900000","GIXAUT":"54800","876073":"50000000","GI3L1T":"1600","GIXF6C":"4100","GIXY2T":"22600","876074":"20229369.86","876077":"20000000","876079":"10558465.75","87606W":"20494027.39","GIXN8T":"5 ...

# %% [markdown]
# user.balance
# user.position
# user.entrust
# user.buy('162411', price=0.55, amount=100)
# user.sell('162411', price=0.55, amount=100)
# user.cancel_entrust('委托单号', '股票代码')
# user.exchangebill   # 查询最近30天的交割单
# user.current_deal #当日交割
# user.get_exchangebill('开始日期', '截止日期')   # 指定查询时间段, 日期格式为 "20160214"

# %%
for i in range(100):
    try:
        bal = user.balance
        bal['data']
        
    except:
        print('Failed when tried to get data from your account')
    time.sleep(300)
# Out:
# 2017-01-04 19:11:25,385 [DEBUG] gftrader.py 114: raw response: {"total":1,"data":[{"money_type":"0","current_balance":"463360.61","real_sell_balance":"0","integral_balance":"7000409.15","market_value":"109107.00","foregift_balance":"0","money_type_dict":"人民币","mortgage_balance":"0","enable_balance":"463310.61","interest":"0","real_buy_balance":"0","begin_balance":"463360.61","pre_interest_tax":"0","pre_fine":"0","fetch_balance":"463310.61","correct_balance":"0","fetch_balance_old":"0","net_asset":"572467.61","frozen_balance":"50.00","unfrozen_balance":"0","asset_balance":"572467.61","pre_interest":"58.34","fetch_cash":"463310.61","fine_integral":"0","opfund_market_value":"0","entrust_buy_balance":"0","fund_balance":"463360.61","rate_kind":"0"}],"success":true}
# 2017-01-04 19:16:25,856 [DEBUG] gftrader.py 114: raw response: {"total":1,"data":[{"money_type":"0","current_balance":"463360.61","real_sell_balance":"0","integral_balance":"7000409.15","market_value":"109107.00","foregift_balance":"0","money_type_dict":"人民币","mortgage_balance":"0","enable_balance":"463310.61","interest":"0","real_buy_balance":"0","begin_balance":"463360.61","pre_interest_tax":"0","pre_fine":"0","fetch_balance":"463310.61","correct_balance":"0","fetch_balance_old":"0","net_asset":"572467.61","frozen_balance":"50.00","unfrozen_balance":"0","asset_balance":"572467.61","pre_interest":"58.34","fetch_cash":"463310.61","fine_integral":"0","opfund_market_value":"0","entrust_buy_balance":"0","fund_balance":"463360.61","rate_kind":"0"}],"success":true}
