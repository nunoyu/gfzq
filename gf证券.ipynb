# %%
import easytrader
import time

# %%
user = easytrader.use('gf')

# %%
user.prepare('C:\\Users\\User\\Documents\\gf.json')
# Out:
# 2016-12-14 08:20:01,186 [INFO] gftrader.py 91: login response: {"error_info":"","success":true}
# 2016-12-14 08:20:02,893 [DEBUG] gftrader.py 142: get account info: var __ctxPath='';              var g_stockholders;            var g_ofstockholders;          var g_client;                  var ver='20161214081958';                    var g_config=Ext.decode("{theme:'blue',modal:'stock',tabstyle:1,tabposition:'top',pageSize:10,homeView:'ServiceView',homeViewName:'服务首页'}");  var g_rzrqstockholders;        var g_ggqqstockholders;        var g_currdate='20161214';var g_valid_flag = false;var id_valid_flag = false;g_client = Ext.decode('{"client_risklevel_name":"进取型","client_risklevel":"5","theme":"blue","current_balance":"468196.69","stockholders":[{"exchange_type":"G","stock_account":"A172195775","seat_no":"23206","exchange_name":"","main_flag":"1"},{"exchange_type":"1","stock_account":"A172195775","seat_no":"23206","exchange_name":"上海","main_flag":"1"},{"exchange_type":"2","stock_account":"0097939068","seat_no":"234800","exchange_name":"深圳","main_flag":"1"}],"last_logindate":"2016-12-14","risk":true,"nick_name":"011028812646","last_op_ip":"186.204.55.188","enable_balance":"468146.69","valid_date":"20180607","client_id":"011028812646","client_name":"余勇","internal":539}');g_stockholders=g_client.stockholders;var g_sysarg=Ext.decode('{"sysId":1,"refreshhq":5000,"requestTimeout":10000,"pageLimitMax":500,"riskValidDate":30,"histQueryDays":30}');var PAGE_LIMIT_MAX=g_sysarg.pageLimitMax;var RISK_VALID_DATE=g_sysarg.riskValidDate;var PAGE_LIMIT_MIN=g_config.pageSize==null?10:g_config.pageSize;Ext.Ajax.timeout=10000;var g_errormsg;var g_ZQTYPE="+-GHIQUXYZuL6";var g_sfcgFundAccount=Ext.decode('[{"money_type":"0","bank_no":"f","bank_name":"招商银行存管","bank_account":"6225880110641603","fund_account":"6409286","bkaccount_status":"0","bkaccount_rights":" ","bkaccount_regflag":"2","main_flag":"1","asset_prop":"0"}]');var g_kfjjAccount=Ext.decode('null');var g_noteinfos;var g_noticeinfos=[];var g_custserver = false;        g_custserver = true;        var hyzq_check_flag = "1";        var g_transferCodes = [];var g_transferClients = [];var g_transferProdNavs = [];var g_productStocks = {"GIR96C":"12700","87604H":"40442958.9","GI357T":"1500","GIXY9T":"2900","GF0090":"0","GF0091":"0","GIS64C":"500000","GF0094":"29306195.06","GF0095":"0","GF0092":"91300870.77","GI1H8T":"500","GF0098":"18701008.01","GF0099":"0","GF0096":"0","GF0097":"0","876059":"20000000","GF0089":"0","GIX83T":"16100","876057":"307778630.13","876050":"10381292.54","GI3L3T":"3600","GIR76C":"4200","87656V":"100000000","GI1C4T":"1000","GIR97C":"6700","GI358T":"2000","GIXW1T":"800","87605I":"10175342.46","87605H":"49186738.35","GIS63C":"160000","87605E":"52991780.82","GF0080":"0","GIX42T":"600","GF0081":"0","GIXCZT":"23200","GF0082":"19001197.93","GF0083":"69500000","GF0084":"0","GIX02T":"1800","GIXP9T":"7500","GF0085":"168000000","GI3H3T":"2500","GI1H7T":"500","GF0086":"0","GF0087":"0","GF0088":"0","GIXAZT":"4700","GIX84T":"15600","GIXN9T":"143500","876065":"34395855.83","87605U":"9000000","GIX02F":"1000000","87657W":"61500657.53","GIX43T":"6800","GI378T":"500","GIR77C":"10500","87605L":"30000000","GI359T":"1500","GI1C3T":"1000","87657Q":"300000000","GIXCYT":"2500","GI355T":"500","GIR98C":"5200","87602G":"19700000","GF0076":"0","876029":"83186665.47","GI1H6T":"700","GF0074":"1000068.05","GF0075":"0","GF0072":"0","GF0073":"0","GF0071":"0","876033":"21853998.08","876034":"5127150.68","GF0069":"18781401.11","GF0068":"94100000","GIXAYT":"2500","GF0067":"11100029.46","GI3L5T":"500","GIX241T":"57100","GIXY6T":"500","87602I":"20000000","GIR78C":"11600","87602J":"50000000","GIX268T":"11500","GI1C6T":"2400","876030":"6000000","876557":"100000000","GIR99C":"36600","GIXCXT":"22700","87603B":"61642191.78","GIXY8T":"6000","GI1H5T":"11500","GF0063":"157700000","GIX04T":"500","GF0065":"22559042.4","GF0066":"24175359.54","87602Y":"10000000","GF0060":"704357.59","GF0061":"0","GF0062":"0","87603U":"21100000","876043":"50661643.83","GIXAXT":"500","GF0057":"30075899.83","GIS070":"0","GIX82T":"36400","GF005 ...

# %% [markdown]
# user.balance
# user.position
# user.entrust
# user.buy('162411', price=0.55, amount=100)
# user.sell('162411', price=0.55, amount=100)
# user.cancel_entrust('委托单号', '股票代码')
# user.exchangebill   # 查询最近30天的交割单
# user.current_deal #当日交割
# user.get_exchangebill('开始日期', '截止日期')   # 指定查询时间段, 日期格式为 "20160214"

# %%
'''
import threading
import time
def KeepOnline():
    user.balance
    global timer
    timer = threading.Timer(5.0, KeepOnline)
    timer.start()

if __name__ == "__main__":
    timer = threading.Timer(5.0, KeepOnline )
    timer.start()
'''
# Out:
# '\nimport threading\nimport time\ndef KeepOnline():\n    user.balance\n    global timer\n    timer = threading.Timer(5.0, KeepOnline)\n    timer.start()\n\nif __name__ == "__main__":\n    timer = threading.Timer(5.0, KeepOnline )\n    timer.start()\n'

# %%
bal = user.balance
# Out:
# 2016-12-14 08:20:04,866 [DEBUG] gftrader.py 114: raw response: {"total":1,"data":[{"money_type":"0","current_balance":"468196.69","real_sell_balance":"0","integral_balance":"16860810.56","market_value":"106817.00","foregift_balance":"0","money_type_dict":"人民币","mortgage_balance":"0","enable_balance":"468146.69","interest":"0","real_buy_balance":"0","begin_balance":"468196.69","pre_interest_tax":"0","pre_fine":"0","fetch_balance":"468146.69","correct_balance":"0","fetch_balance_old":"0","net_asset":"575013.69","frozen_balance":"50.00","unfrozen_balance":"0","asset_balance":"575013.69","pre_interest":"140.51","fetch_cash":"468146.69","fine_integral":"0","opfund_market_value":"0","entrust_buy_balance":"0","fund_balance":"468196.69","rate_kind":"0"}],"success":true}

# %%
bal['data']
# Out:
# [{'asset_balance': '575013.69',
#   'begin_balance': '468196.69',
#   'correct_balance': '0',
#   'current_balance': '468196.69',
#   'enable_balance': '468146.69',
#   'entrust_buy_balance': '0',
#   'fetch_balance': '468146.69',
#   'fetch_balance_old': '0',
#   'fetch_cash': '468146.69',
#   'fine_integral': '0',
#   'foregift_balance': '0',
#   'frozen_balance': '50.00',
#   'fund_balance': '468196.69',
#   'integral_balance': '16860810.56',
#   'interest': '0',
#   'market_value': '106817.00',
#   'money_type': '0',
#   'money_type_dict': '人民币',
#   'mortgage_balance': '0',
#   'net_asset': '575013.69',
#   'opfund_market_value': '0',
#   'pre_fine': '0',
#   'pre_interest': '140.51',
#   'pre_interest_tax': '0',
#   'rate_kind': '0',
#   'real_buy_balance': '0',
#   'real_sell_balance': '0',
#   'unfrozen_balance': '0'}]
